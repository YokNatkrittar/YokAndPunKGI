# %%
import pandas as pd
from rich.live import Live
from rich.table import Table
from rich.panel import Panel
from rich.layout import Layout
import importlib
import re

# Import trading library
from tradeSim import TradeSim
from tradeSim import StrategyHandler

# %% [markdown]
# # **__Trading simulation__**
#
# Welcome to the simulation platform!
#
# This Python-based environment is designed to replicate a realistic trading experience using the SET50 daily ticks dataset. It supports essential features like real-time data streaming, order matching, portfolio management, and fee calculations, giving you everything you need to build and test your algorithmic trading strategies.
#
# Each participant begins with a virtual portfolio containing 10,000,000 Baht in starting capital. Your challenge is to design effective trading algorithms and compete with other teams to generate the highest return. Think smart, trade fast, and enjoy the competition!
#
# ---

# %% [markdown]
# ### **Import Daily ticks information for trading infomation**
# For each day within compitition, the tick information will be provided daily

# %%
#TODO: Change ticks information daily
daily_ticks = "./marketInfo/ticks/2025-10-15.csv"

df = pd.read_csv(daily_ticks)
df['TradeDateTime'] = pd.to_datetime(df['TradeDateTime'])
grouped = df.groupby('ShareCode')
# Out:
# /var/folders/ty/81c5bnz15rd5t6qk6qlqn29h0000gn/T/ipykernel_97054/356443102.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['TradeDateTime'] = pd.to_datetime(df['TradeDateTime'])

# %% [markdown]
# ### **Now, name your team!**
#
# The code section below will create your trading simulation class using the team name you provide.
#
# - Your team name will be set as the `owner` of the `TraderPortfolio` from `trading_sim`.
# - The `SimExecution` class will handle order execution for buying stocks in the market.
#
# **Team name requirements:**
# - Must use English letters or numbers
# - No spaces allowed
# - Hyphens (`-`) and underscores (`_`) are allowed
# - Must be **30 characters or fewer**

# %%
#TODO: Replace with your team name
team_name = "YokAndPun"
strategy_name = "YokAndPun_strategy"

pattern = r'^[A-Za-z0-9-_]{1,30}$'
if not bool(re.match(pattern, team_name)) or not bool(re.match(pattern, strategy_name)):
    raise ValueError("Team name or strategy name is invalid. Please use only alphanumeric characters, hyphens, and underscores, with a maximum length of 30 characters.")

# Init trade system
trading_Sim = TradeSim.tradeSim(team_name) 
strategy_runner = trading_Sim.get_strategy_runner()
# Out:
# [INFO] Loaded existing portfolio from 'result/YokAndPun/YokAndPun_portfolio.json'

# %% [markdown]
# ### **Craft Your Strategy**
#
# To simulate your trading strategy within the platform,
# you must create your own strategy class by inheriting from the `strategy_template` class.
#
# Once you've finished writing or are ready to test it,
# run the code below to import your strategy into this notebook.

# %%
try:
    strategy_module = importlib.import_module(f"strategy.{strategy_name}")
    importlib.reload(strategy_module)
except ImportError as e:
    active_strategy_fn = None
    print(f"Error in strategy module: {e}")
    
strategy_class = getattr(strategy_module, strategy_name, None)

# %% [markdown]
# ----
#
# ## **The Simulation**
# The simulation models a real-time market environment using a thread handler, where each thread streams data for a specific symbol in the SET50 index, as provided in ```Daily_ticks.CSV```. This section of the code iterates through all entries in the CSV file, applying each competitor’s strategy based on the current market data. During the streaming process, the system attempts to match any pending orders in the order books and updates the market prices in the competitors’ portfolios for any held stocks.
# ##### *For more detailed explanation please look at document file*
# >By setting `with_visual` to `False`, the simulation runs significantly faster.

# %%
#TODO: Change the `with_visual` according to your preference
# True if you want to see the visual simulation  
# False if you want to finish the simulation faster
with_visual = False

# %%
latest_prices = {}

# === Render Helpers ===
def render_market_table():
    table = Table(title="📈 Market Stream")
    table.add_column("Symbol")
    table.add_column("Last Price", justify="right")
    table.add_column("Volume", justify="right")
    table.add_column("Flag", justify="right")

    snapshot = dict(latest_prices)  # copy to avoid mid-update issues

    for sym, data in snapshot.items():
        table.add_row(
            sym,
            f"{data['price']:.2f}",
            str(data["volume"]),
            data["Flag"]
        )
    return table


def render_portfolio_table():
    table = Table(title=f"💼 Portfolio: {strategy_runner.get_owner()}", expand=True)
    table.add_column("Cash Balance", no_wrap=True, width=18)
    table.add_column("Symbol")
    table.add_column("Actual Vol", justify="right")
    table.add_column("Buy Price", justify="right")
    table.add_column("Market Price", justify="right")
    table.add_column("Average Cost", justify="right")
    table.add_column("Amount Cost", justify="right")
    table.add_column("Market Value", justify="right")
    table.add_column("Unrealized", justify="right")
    table.add_column("Unreal. %", justify="right")
    table.add_column("Realized", justify="right")
    table.add_column("Buy Time", justify="center")

    stock_infos = strategy_runner.get_all_stocks_info()
    cash_str = f"{strategy_runner.get_cash_balance():,.2f}"
    cash_displayed = False

    if not stock_infos:
        table.add_row(cash_str, "-", "0", "-", "-", "-", "-", "-", "-", "-", "-", "-")
    else:
        for stock in stock_infos:
            table.add_row(
                cash_str if not cash_displayed else "",
                stock["Symbol"],
                str(stock["Actual Volume"]),
                f"{stock['Buy Price']:.2f}",
                f"{stock['Market Price']:.2f}",
                f"{stock['Average Cost']:.2f}",
                f"{stock['Amount Cost']:.2f}",
                f"{stock['Market Value']:.2f}",
                f"{stock['Unrealized P&L']:.2f}",
                f"{stock['Unrealized %']:.2f}%",
                f"{stock['Realized P&L']:.2f}",
                stock["Buy time"]
            )
            cash_displayed = True

    # Add metrics summary
    table.add_section()
    table.add_row("🔢 Metrics", "", "", "", "", "", "", "", "", "", "", "")
    table.add_row("ROI (%)", f"{strategy_runner.get_roi():.2f}%", "", "", "", "", "", "", "", "", "", "")
    table.add_row("Max Drawdown (%)", f"{strategy_runner.get_max_draw_down():.2f}%", "", "", "", "", "", "", "", "", "", "")
    table.add_row("Win Count", str(strategy_runner.get_number_of_wins()), "", "", "", "", "", "", "", "", "", "")
    table.add_row("Sell Count", str(strategy_runner.get_number_of_sells()), "", "", "", "", "", "", "", "", "", "")
    return table


def render_layout():
    layout = Layout()
    layout.split_column(
        Layout(Panel(render_market_table(), expand=True), name="market"),
        Layout(Panel(render_portfolio_table(), expand=True), name="portfolio")
    )
    return layout


# === Simulation Core ===
handlers = {
    symbol: StrategyHandler.StrategyHandler(strategy_class, strategy_runner)
    for symbol, _ in grouped
}

max_length = max(len(group) for _, group in grouped)
layout = render_layout()

if with_visual:
    with Live(layout, refresh_per_second=2):
        for tick in range(max_length):
            for symbol, data in grouped:
                if tick >= len(data):
                    continue

                row = data.iloc[tick]
                price_update = {row['ShareCode']: row['LastPrice']}

                handler = handlers[symbol]
                handler.process_row(row)

                if not trading_Sim.isOrderbooksEmpty():
                    trading_Sim.isMatch(row)

                trading_Sim.update_market_prices(price_update)

                latest_prices[symbol] = {
                    "price": row['LastPrice'],
                    "volume": row['Volume'],
                    "Flag": row['Flag']
                }

            layout["market"].update(Panel(render_market_table()))
            layout["portfolio"].update(Panel(render_portfolio_table()))

else:
    # Headless (no visual mode)
    for tick in range(max_length):
        for symbol, data in grouped:
            if tick >= len(data):
                continue

            row = data.iloc[tick]
            price_update = {row['ShareCode']: row['LastPrice']}

            handler = handlers[symbol]
            handler.process_row(row)

            if not trading_Sim.isOrderbooksEmpty():
                trading_Sim.isMatch(row)

            trading_Sim.update_market_prices(price_update)

            latest_prices[symbol] = {
                "price": row['LastPrice'],
                "volume": row['Volume'],
                "Flag": row['Flag']
            }

# === Final flush/save ===
layout["market"].update(Panel(render_market_table()))
layout["portfolio"].update(Panel(render_portfolio_table()))

trading_Sim.flushTransactionLog()
trading_Sim.flushErrorLogger()
trading_Sim.create_transaction_summarize(team_name)
trading_Sim.save_portfolio()

trading_date = df['TradeDateTime'].dt.date.iloc[0]
trading_Sim.save_summary_csv(trading_date)
# Out:
# TP: AOT at 40.75. Buy: 40.07
# TP: AOT at 40.75. Buy: 40.07
# TP: AOT at 40.75. Buy: 39.82
# TP: AOT at 40.75. Buy: 39.82
# TP: AOT at 40.75. Buy: 39.57
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BJC at 19.50. Buy: 19.33
# TP: BJC at 19.50. Buy: 19.13
# TP: BJC at 19.50. Buy: 19.13
# TP: COM7 at 26.50. Buy: 26.29
# TP: COM7 at 26.50. Buy: 26.29
# TP: COM7 at 26.50. Buy: 26.29
# TP: COM7 at 26.50. Buy: 26.29
# TP: COM7 at 26.50. Buy: 26.29
# TP: CRC at 20.40. Buy: 20.23
# TP: CRC at 20.40. Buy: 20.13
# TP: KBANK at 167.50. Buy: 166.28
# SL: LH at 4.10. Buy: 4.27
# SL: LH at 4.10. Buy: 4.25
# SL: LH at 4.10. Buy: 4.25
# SL: LH at 4.10. Buy: 4.25
# TP: RATCH at 28.00. Buy: 27.80
# TP: RATCH at 28.00. Buy: 27.80
# TP: RATCH at 28.00. Buy: 27.80
# TP: RATCH at 28.00. Buy: 27.80
# TP: RATCH at 28.00. Buy: 27.80
# TP: SCGP at 17.50. Buy: 17.33
# TP: TLI at 10.40. Buy: 10.22
# TP: TLI at 10.40. Buy: 10.22
# TP: TLI at 10.40. Buy: 10.22
# TP: TLI at 10.40. Buy: 10.22
# TP: TLI at 10.40. Buy: 10.22
# TP: AOT at 41.00. Buy: 40.07
# TP: AOT at 41.00. Buy: 40.07
# TP: AOT at 41.00. Buy: 39.82
# TP: AOT at 41.00. Buy: 39.82
# TP: AOT at 41.00. Buy: 39.57
# TP: BJC at 19.50. Buy: 19.33
# TP: BJC at 19.50. Buy: 19.13
# TP: BJC at 19.50. Buy: 19.13
# TP: CCET at 5.85. Buy: 5.81
# TP: CCET at 5.85. Buy: 5.81
# TP: CCET at 5.85. Buy: 5.81
# TP: CCET at 5.85. Buy: 5.81
# TP: CCET at 5.85. Buy: 5.81
# TP: CRC at 20.30. Buy: 20.13
# SL: LH at 4.12. Buy: 4.27
# SL: LH at 4.12. Buy: 4.25
# SL: LH at 4.12. Buy: 4.25
# SL: LH at 4.12. Buy: 4.25
# BUY MTC at 39.50. Dip triggered (Price < EMA - 0.5%)
# TP: OR at 13.30. Buy: 13.22
# TP: OR at 13.30. Buy: 13.22
# TP: OR at 13.30. Buy: 13.22
# TP: OR at 13.30. Buy: 13.22
# TP: OR at 13.30. Buy: 13.22
# TP: RATCH at 28.00. Buy: 27.80
# TP: RATCH at 28.00. Buy: 27.80
# TP: RATCH at 28.00. Buy: 27.80
# TP: RATCH at 28.00. Buy: 27.80
# TP: RATCH at 28.00. Buy: 27.80
# TP: SCB at 128.50. Buy: 127.71
# TP: SCB at 128.50. Buy: 127.71
# TP: SCGP at 17.60. Buy: 17.33
# TP: TLI at 10.30. Buy: 10.22
# TP: TLI at 10.30. Buy: 10.22
# TP: TLI at 10.30. Buy: 10.22
# TP: TLI at 10.30. Buy: 10.22
# TP: TLI at 10.30. Buy: 10.22
# BUY VGI at 1.36. Dip triggered (Price < EMA - 0.5%)
# TP: AOT at 40.75. Buy: 39.82
# TP: AOT at 40.75. Buy: 39.57
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BJC at 19.40. Buy: 19.13
# TP: CRC at 20.30. Buy: 20.13
# TP: RATCH at 28.00. Buy: 27.80
# TP: RATCH at 28.00. Buy: 27.80
# TP: SCGP at 17.60. Buy: 17.33
# TP: TLI at 10.40. Buy: 10.22
# TP: TLI at 10.40. Buy: 10.22
# TP: TLI at 10.40. Buy: 10.22
# TP: TLI at 10.40. Buy: 10.22
# TP: TLI at 10.40. Buy: 10.22
# TP: AOT at 40.75. Buy: 39.57
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: CRC at 20.40. Buy: 20.23
# TP: CRC at 20.40. Buy: 20.13
# TP: RATCH at 28.00. Buy: 27.80
# TP: SCGP at 17.60. Buy: 17.33
# TP: TLI at 10.40. Buy: 10.22
# TP: TLI at 10.40. Buy: 10.22
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: CCET at 5.85. Buy: 5.81
# TP: CCET at 5.85. Buy: 5.81
# TP: CRC at 20.40. Buy: 20.23
# TP: CRC at 20.40. Buy: 20.13
# TP: OR at 13.30. Buy: 13.22
# TP: OR at 13.30. Buy: 13.22
# TP: OR at 13.30. Buy: 13.22
# TP: OR at 13.30. Buy: 13.22
# TP: OR at 13.30. Buy: 13.22
# TP: SCGP at 17.60. Buy: 17.33
# BUY TLI at 10.30. Dip triggered (Price < EMA - 0.5%)
# TP: TLI at 10.30. Buy: 10.22
# TP: VGI at 1.38. Buy: 1.36
# TP: VGI at 1.38. Buy: 1.36
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BEM at 5.90. Buy: 5.11
# TP: BEM at 5.90. Buy: 5.11
# TP: BEM at 5.90. Buy: 5.11
# TP: BEM at 5.90. Buy: 5.11
# TP: BEM at 5.90. Buy: 5.11
# TP: COM7 at 26.50. Buy: 26.29
# TP: COM7 at 26.50. Buy: 26.29
# TP: COM7 at 26.50. Buy: 26.29
# TP: COM7 at 26.50. Buy: 26.29
# TP: COM7 at 26.50. Buy: 26.29
# TP: CRC at 20.40. Buy: 20.23
# TP: CRC at 20.40. Buy: 20.13
# TP: OR at 13.30. Buy: 13.22
# TP: OR at 13.30. Buy: 13.22
# TP: SCGP at 17.60. Buy: 17.33
# BUY TLI at 10.30. Dip triggered (Price < EMA - 0.5%)
# TP: TLI at 10.30. Buy: 10.22
# TP: VGI at 1.38. Buy: 1.36
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: COM7 at 26.50. Buy: 26.29
# TP: COM7 at 26.50. Buy: 26.29
# TP: CRC at 20.40. Buy: 20.23
# TP: CRC at 20.40. Buy: 20.13
# TP: OR at 13.30. Buy: 13.22
# TP: TLI at 10.40. Buy: 10.22
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: CCET at 5.85. Buy: 5.81
# TP: COM7 at 26.50. Buy: 26.29
# TP: CRC at 20.40. Buy: 20.23
# TP: CRC at 20.40. Buy: 20.13
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: CRC at 20.40. Buy: 20.13
# SL: GPSC at 39.50. Buy: 40.82
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# BUY GPSC at 39.50. Dip triggered (Price < EMA - 0.5%)
# BUY RATCH at 27.75. Dip triggered (Price < EMA - 0.5%)
# BUY TLI at 10.30. Dip triggered (Price < EMA - 0.5%)
# BUY BEM at 5.05. Dip triggered (Price < EMA - 0.5%)
# TP: SCB at 128.50. Buy: 127.71
# TP: SCB at 128.50. Buy: 127.71
# BUY TLI at 10.30. Dip triggered (Price < EMA - 0.5%)
# TP: SCB at 128.50. Buy: 127.71
# TP: GPSC at 40.50. Buy: 39.82
# TP: GPSC at 40.50. Buy: 39.82
# BUY VGI at 1.37. Dip triggered (Price < EMA - 0.5%)
# BUY AOT at 40.00. Dip triggered (Price < EMA - 0.5%)
# TP: GPSC at 40.50. Buy: 39.82
# TP: AOT at 40.75. Buy: 40.32
# TP: GPSC at 40.50. Buy: 39.82
# TP: GPSC at 40.50. Buy: 39.82
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# BUY CCET at 5.80. Dip triggered (Price < EMA - 0.5%)
# TP: KBANK at 167.50. Buy: 166.28
# BUY BEM at 5.05. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.80. Dip triggered (Price < EMA - 0.5%)
# BUY BEM at 5.05. Dip triggered (Price < EMA - 0.5%)
# TP: KTC at 30.50. Buy: 30.30
# TP: KTC at 30.50. Buy: 30.30
# TP: KTC at 30.50. Buy: 30.30
# TP: KTC at 30.50. Buy: 30.30
# TP: KTC at 30.50. Buy: 30.30
# BUY TLI at 10.20. Dip triggered (Price < EMA - 0.5%)
# TP: KTC at 30.50. Buy: 30.30
# TP: KTC at 30.50. Buy: 30.30
# TP: KTC at 30.50. Buy: 30.30
# BUY BBL at 150.00. Dip triggered (Price < EMA - 0.5%)
# TP: TISCO at 104.50. Buy: 103.67
# BUY CPALL at 47.00. Dip triggered (Price < EMA - 0.5%)
# BUY CPALL at 47.00. Dip triggered (Price < EMA - 0.5%)
# SL: MTC at 38.75. Buy: 39.82
# BUY BCP at 29.25. Dip triggered (Price < EMA - 0.5%)
# BUY GULF at 42.75. Dip triggered (Price < EMA - 0.5%)
# SL: GULF at 42.75. Buy: 44.07
# BUY MTC at 39.00. Dip triggered (Price < EMA - 0.5%)
# BUY GULF at 43.00. Dip triggered (Price < EMA - 0.5%)
# TP: HMPRO at 7.15. Buy: 7.06
# TP: HMPRO at 7.15. Buy: 7.06
# TP: HMPRO at 7.15. Buy: 7.06
# TP: HMPRO at 7.15. Buy: 7.06
# SL: MTC at 38.75. Buy: 39.82
# SL: SCC at 205.00. Buy: 211.35
# BUY COM7 at 26.00. Dip triggered (Price < EMA - 0.5%)
# BUY GULF at 43.00. Dip triggered (Price < EMA - 0.5%)
# BUY MTC at 38.75. Dip triggered (Price < EMA - 0.5%)
# SL: MTC at 38.75. Buy: 39.82
# TP: COM7 at 26.50. Buy: 26.29
# TP: GULF at 44.25. Buy: 43.07
# TP: GULF at 44.25. Buy: 43.32
# TP: GULF at 44.25. Buy: 43.32
# BUY MTC at 38.75. Dip triggered (Price < EMA - 0.5%)
# SL: MTC at 38.75. Buy: 39.82
# TP: WHA at 3.68. Buy: 3.65
# TP: GULF at 44.25. Buy: 43.32
# BUY MTC at 38.75. Dip triggered (Price < EMA - 0.5%)
# SL: MTC at 38.75. Buy: 39.82
# TP: WHA at 3.68. Buy: 3.65
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: WHA at 3.68. Buy: 3.65
# TP: BCP at 29.75. Buy: 29.55
# TP: TISCO at 104.50. Buy: 103.67
# TP: TISCO at 104.50. Buy: 103.67
# TP: WHA at 3.68. Buy: 3.65
# TP: WHA at 3.68. Buy: 3.65
# BUY COM7 at 26.50. Dip triggered (Price < EMA - 0.5%)
# BUY BCP at 29.50. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.75. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.75. Dip triggered (Price < EMA - 0.5%)
# TP: TIDLOR at 21.30. Buy: 21.14
# BUY HMPRO at 7.05. Dip triggered (Price < EMA - 0.5%)
# TP: BBL at 152.00. Buy: 150.75
# TP: CCET at 5.85. Buy: 5.81
# TP: CCET at 5.85. Buy: 5.81
# BUY VGI at 1.37. Dip triggered (Price < EMA - 0.5%)
# BUY MTC at 38.50. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.75. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.75. Dip triggered (Price < EMA - 0.5%)
# TP: MTC at 39.50. Buy: 39.07
# TP: MTC at 39.50. Buy: 39.07
# TP: MTC at 39.50. Buy: 39.07
# TP: MTC at 39.50. Buy: 38.82
# BUY VGI at 1.37. Dip triggered (Price < EMA - 0.5%)
# TP: BEM at 5.15. Buy: 5.11
# TP: BEM at 5.15. Buy: 5.11
# TP: BEM at 5.15. Buy: 5.11
# TP: BEM at 5.15. Buy: 5.11
# TP: BEM at 5.15. Buy: 5.11
# TP: BEM at 5.15. Buy: 5.11
# TP: BEM at 5.15. Buy: 5.11
# TP: MTC at 39.75. Buy: 39.07
# TP: MTC at 39.75. Buy: 39.07
# TP: MTC at 39.75. Buy: 38.82
# TP: BEM at 5.15. Buy: 5.11
# TP: MTC at 40.00. Buy: 38.82
# BUY CRC at 20.00. Dip triggered (Price < EMA - 0.5%)
# SL: TRUE at 10.90. Buy: 11.22
# SL: TRUE at 10.90. Buy: 11.22
# SL: TRUE at 10.90. Buy: 11.22
# SL: TRUE at 10.90. Buy: 11.22
# SL: TRUE at 10.90. Buy: 11.22
# BUY COM7 at 26.25. Dip triggered (Price < EMA - 0.5%)
# TP: CRC at 20.30. Buy: 20.13
# BUY TRUE at 11.00. Dip triggered (Price < EMA - 0.5%)
# TP: TRUE at 11.20. Buy: 11.12
# BUY GULF at 43.75. Dip triggered (Price < EMA - 0.5%)
# BUY AOT at 40.25. Dip triggered (Price < EMA - 0.5%)
# BUY MTC at 39.25. Dip triggered (Price < EMA - 0.5%)
# BUY BEM at 5.10. Dip triggered (Price < EMA - 0.5%)
# BUY BEM at 5.10. Dip triggered (Price < EMA - 0.5%)
# BUY RATCH at 27.50. Dip triggered (Price < EMA - 0.5%)
# TP: VGI at 1.39. Buy: 1.37
# BUY IVL at 20.60. Dip triggered (Price < EMA - 0.5%)
# BUY COM7 at 26.25. Dip triggered (Price < EMA - 0.5%)
# TP: IVL at 20.90. Buy: 20.73
# BUY COM7 at 26.25. Dip triggered (Price < EMA - 0.5%)
# BUY KKP at 61.25. Dip triggered (Price < EMA - 0.5%)
# TP: HMPRO at 7.15. Buy: 7.06
# TP: HMPRO at 7.15. Buy: 7.06
# TP: HMPRO at 7.15. Buy: 7.06
# BUY RATCH at 27.50. Dip triggered (Price < EMA - 0.5%)
# TP: HMPRO at 7.15. Buy: 7.06
# BUY RATCH at 27.50. Dip triggered (Price < EMA - 0.5%)
# BUY BEM at 5.10. Dip triggered (Price < EMA - 0.5%)
# BUY RATCH at 27.50. Dip triggered (Price < EMA - 0.5%)
# BUY OR at 13.30. Dip triggered (Price < EMA - 0.5%)
# TP: TCAP at 50.50. Buy: 50.08
# TP: COM7 at 26.75. Buy: 26.54
# TP: COM7 at 26.75. Buy: 26.54
# TP: COM7 at 26.75. Buy: 26.54
# TP: KKP at 62.00. Buy: 61.60
# TP: COM7 at 26.75. Buy: 26.54
# TP: COM7 at 26.75. Buy: 26.54
# TP: MTC at 40.00. Buy: 39.57
# TP: COM7 at 26.75. Buy: 26.54
# BUY MTC at 39.25. Dip triggered (Price < EMA - 0.5%)
# BUY MTC at 39.25. Dip triggered (Price < EMA - 0.5%)
# TP: MTC at 40.00. Buy: 39.57
# TP: MTC at 40.00. Buy: 39.57
# TP: MTC at 40.00. Buy: 39.57
# TP: KTB at 24.70. Buy: 24.54
# TP: KTB at 24.70. Buy: 24.54
# BUY BEM at 5.10. Dip triggered (Price < EMA - 0.5%)
# TP: CPALL at 47.75. Buy: 47.33
# TP: CPALL at 47.75. Buy: 47.33
# TP: CPALL at 47.75. Buy: 47.33
# BUY KKP at 61.25. Dip triggered (Price < EMA - 0.5%)
# TP: KTB at 24.70. Buy: 24.54
# TP: KKP at 62.00. Buy: 61.60
# TP: KTB at 24.70. Buy: 24.54
# SL: CCET at 5.70. Buy: 5.86
# BUY BEM at 5.05. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.70. Dip triggered (Price < EMA - 0.5%)
# TP: BANPU at 4.44. Buy: 4.41
# TP: VGI at 1.40. Buy: 1.38
# TP: VGI at 1.40. Buy: 1.38
# TP: VGI at 1.40. Buy: 1.38
# TP: BEM at 5.15. Buy: 5.11
# TP: BEM at 5.15. Buy: 5.11
# TP: TLI at 10.40. Buy: 10.32
# TP: BEM at 5.15. Buy: 5.11
# TP: TLI at 10.40. Buy: 10.32
# TP: VGI at 1.40. Buy: 1.38
# TP: TLI at 10.40. Buy: 10.32
# TP: TLI at 10.40. Buy: 10.32
# TP: TLI at 10.40. Buy: 10.32
# TP: BEM at 5.15. Buy: 5.11
# BUY HMPRO at 7.05. Dip triggered (Price < EMA - 0.5%)
# BUY OR at 13.30. Dip triggered (Price < EMA - 0.5%)
# TP: BEM at 5.15. Buy: 5.11
# BUY HMPRO at 7.05. Dip triggered (Price < EMA - 0.5%)
# BUY AOT at 40.25. Dip triggered (Price < EMA - 0.5%)
# BUY MTC at 39.75. Dip triggered (Price < EMA - 0.5%)
# BUY MTC at 39.50. Dip triggered (Price < EMA - 0.5%)
# BUY COM7 at 26.50. Dip triggered (Price < EMA - 0.5%)
# BUY MTC at 39.50. Dip triggered (Price < EMA - 0.5%)
# BUY MTC at 39.50. Dip triggered (Price < EMA - 0.5%)
# BUY COM7 at 26.50. Dip triggered (Price < EMA - 0.5%)
# BUY MTC at 39.25. Dip triggered (Price < EMA - 0.5%)
# TP: MINT at 22.60. Buy: 22.44
# TP: MINT at 22.60. Buy: 22.44
# BUY EGCO at 136.50. Dip triggered (Price < EMA - 0.5%)
# TP: MINT at 22.60. Buy: 22.44
# TP: MINT at 22.60. Buy: 22.44
# TP: MINT at 22.60. Buy: 22.44
# TP: MINT at 22.60. Buy: 22.44
# TP: MINT at 22.60. Buy: 22.44
# TP: MINT at 22.60. Buy: 22.44
# BUY VGI at 1.38. Dip triggered (Price < EMA - 0.5%)
# BUY BBL at 151.50. Dip triggered (Price < EMA - 0.5%)
# BUY KTC at 30.25. Dip triggered (Price < EMA - 0.5%)
# BUY OR at 13.30. Dip triggered (Price < EMA - 0.5%)
# TP: MTC at 40.25. Buy: 39.82
# TP: MTC at 40.25. Buy: 39.82
# TP: MTC at 40.25. Buy: 39.82
# TP: MTC at 40.25. Buy: 39.57
# TP: OSP at 16.60. Buy: 16.43
# TP: MINT at 22.60. Buy: 22.44
# TP: MTC at 40.25. Buy: 39.82
# TP: MTC at 40.25. Buy: 39.82
# TP: MTC at 40.25. Buy: 39.57
# TP: CCET at 5.80. Buy: 5.76
# TP: MTC at 40.00. Buy: 39.57
# TP: OSP at 16.60. Buy: 16.43
# BUY KTC at 30.25. Dip triggered (Price < EMA - 0.5%)
# BUY BEM at 5.05. Dip triggered (Price < EMA - 0.5%)
# BUY COM7 at 26.50. Dip triggered (Price < EMA - 0.5%)
# BUY KTC at 30.25. Dip triggered (Price < EMA - 0.5%)
# TP: OSP at 16.60. Buy: 16.43
# BUY OR at 13.30. Dip triggered (Price < EMA - 0.5%)
# BUY VGI at 1.37. Dip triggered (Price < EMA - 0.5%)
# BUY OSP at 16.40. Dip triggered (Price < EMA - 0.5%)
# BUY COM7 at 26.50. Dip triggered (Price < EMA - 0.5%)
# BUY COM7 at 26.50. Dip triggered (Price < EMA - 0.5%)
# BUY CPALL at 47.25. Dip triggered (Price < EMA - 0.5%)
# BUY BEM at 5.05. Dip triggered (Price < EMA - 0.5%)
# BUY BEM at 5.05. Dip triggered (Price < EMA - 0.5%)
# BUY BEM at 5.05. Dip triggered (Price < EMA - 0.5%)
# BUY TRUE at 11.10. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.70. Dip triggered (Price < EMA - 0.5%)
# TP: BCP at 30.00. Buy: 29.80
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# BUY AWC at 2.08. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.08. Dip triggered (Price < EMA - 0.5%)
# BUY HMPRO at 7.10. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.08. Dip triggered (Price < EMA - 0.5%)
# BUY TLI at 10.20. Dip triggered (Price < EMA - 0.5%)
# BUY TIDLOR at 21.20. Dip triggered (Price < EMA - 0.5%)
# BUY TIDLOR at 21.20. Dip triggered (Price < EMA - 0.5%)
# BUY TLI at 10.20. Dip triggered (Price < EMA - 0.5%)
# BUY TLI at 10.20. Dip triggered (Price < EMA - 0.5%)
# TP: RATCH at 28.00. Buy: 27.80
# TP: RATCH at 28.00. Buy: 27.80
# TP: RATCH at 28.00. Buy: 27.80
# TP: RATCH at 28.00. Buy: 27.80
# BUY MTC at 40.00. Dip triggered (Price < EMA - 0.5%)
# TP: RATCH at 28.00. Buy: 27.80
# TP: RATCH at 28.00. Buy: 27.80
# TP: RATCH at 28.00. Buy: 27.80
# TP: KTC at 30.75. Buy: 30.55
# TP: KTC at 30.75. Buy: 30.55
# TP: KTC at 30.75. Buy: 30.55
# BUY MTC at 40.00. Dip triggered (Price < EMA - 0.5%)
# TP: KTC at 30.75. Buy: 30.55
# BUY MTC at 40.00. Dip triggered (Price < EMA - 0.5%)
# BUY BEM at 5.05. Dip triggered (Price < EMA - 0.5%)
# BUY MTC at 40.00. Dip triggered (Price < EMA - 0.5%)
# TP: RATCH at 28.00. Buy: 27.80
# TP: CCET at 5.80. Buy: 5.76
# TP: CCET at 5.80. Buy: 5.76
# TP: CCET at 5.80. Buy: 5.76
# TP: CCET at 5.80. Buy: 5.76
# SL: COM7 at 26.00. Buy: 26.79
# SL: COM7 at 26.00. Buy: 26.79
# SL: COM7 at 26.00. Buy: 26.79
# SL: COM7 at 26.00. Buy: 26.79
# SL: COM7 at 26.00. Buy: 26.79
# BUY BCP at 29.25. Dip triggered (Price < EMA - 0.5%)
# TP: CCET at 5.80. Buy: 5.76
# TP: CCET at 5.80. Buy: 5.76
# BUY BCP at 29.25. Dip triggered (Price < EMA - 0.5%)
# TP: CCET at 5.80. Buy: 5.76
# TP: CCET at 5.80. Buy: 5.76
# TP: CCET at 5.80. Buy: 5.76
# BUY RATCH at 27.75. Dip triggered (Price < EMA - 0.5%)
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# BUY BCP at 29.25. Dip triggered (Price < EMA - 0.5%)
# BUY KKP at 61.25. Dip triggered (Price < EMA - 0.5%)
# BUY RATCH at 27.75. Dip triggered (Price < EMA - 0.5%)
# BUY KKP at 61.00. Dip triggered (Price < EMA - 0.5%)
# TP: KKP at 61.75. Buy: 61.35
# TP: KKP at 61.75. Buy: 61.35
# BUY TRUE at 11.10. Dip triggered (Price < EMA - 0.5%)
# BUY KTC at 30.50. Dip triggered (Price < EMA - 0.5%)
# BUY TRUE at 11.10. Dip triggered (Price < EMA - 0.5%)
# BUY TRUE at 11.10. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.75. Dip triggered (Price < EMA - 0.5%)
# BUY KTC at 30.50. Dip triggered (Price < EMA - 0.5%)
# BUY RATCH at 27.75. Dip triggered (Price < EMA - 0.5%)
# BUY VGI at 1.37. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.75. Dip triggered (Price < EMA - 0.5%)
# TP: MTC at 40.75. Buy: 40.32
# TP: MTC at 40.75. Buy: 40.32
# TP: MTC at 40.75. Buy: 40.32
# TP: MTC at 40.75. Buy: 40.32
# BUY TIDLOR at 21.20. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.75. Dip triggered (Price < EMA - 0.5%)
# BUY KTC at 30.50. Dip triggered (Price < EMA - 0.5%)
# BUY COM7 at 26.50. Dip triggered (Price < EMA - 0.5%)
# TP: HMPRO at 7.20. Buy: 7.11
# TP: HMPRO at 7.20. Buy: 7.11
# TP: HMPRO at 7.20. Buy: 7.11
# BUY TRUE at 11.10. Dip triggered (Price < EMA - 0.5%)
# TP: HMPRO at 7.20. Buy: 7.11
# BUY KTC at 30.50. Dip triggered (Price < EMA - 0.5%)
# BUY RATCH at 27.75. Dip triggered (Price < EMA - 0.5%)
# BUY COM7 at 26.50. Dip triggered (Price < EMA - 0.5%)
# BUY COM7 at 26.50. Dip triggered (Price < EMA - 0.5%)
# BUY GPSC at 39.75. Dip triggered (Price < EMA - 0.5%)
# BUY GPSC at 39.75. Dip triggered (Price < EMA - 0.5%)
# BUY GPSC at 39.75. Dip triggered (Price < EMA - 0.5%)
# BUY BCP at 29.25. Dip triggered (Price < EMA - 0.5%)
# BUY BCP at 29.25. Dip triggered (Price < EMA - 0.5%)
# BUY TLI at 10.20. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.75. Dip triggered (Price < EMA - 0.5%)
# BUY BCP at 29.25. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.75. Dip triggered (Price < EMA - 0.5%)
# TP: BEM at 5.15. Buy: 5.11
# TP: BEM at 5.15. Buy: 5.11
# TP: BEM at 5.15. Buy: 5.11
# TP: BEM at 5.15. Buy: 5.11
# TP: BEM at 5.15. Buy: 5.11
# BUY COM7 at 26.50. Dip triggered (Price < EMA - 0.5%)
# BUY BEM at 5.05. Dip triggered (Price < EMA - 0.5%)
# BUY COM7 at 26.50. Dip triggered (Price < EMA - 0.5%)
# TP: RATCH at 28.25. Buy: 28.05
# TP: RATCH at 28.25. Buy: 28.05
# TP: RATCH at 28.25. Buy: 28.05
# TP: RATCH at 28.25. Buy: 28.05
# BUY OR at 13.40. Dip triggered (Price < EMA - 0.5%)
# BUY GPSC at 39.75. Dip triggered (Price < EMA - 0.5%)
# TP: RATCH at 28.25. Buy: 28.05
# TP: RATCH at 28.25. Buy: 28.05
# TP: RATCH at 28.25. Buy: 28.05
# BUY BH at 173.00. Dip triggered (Price < EMA - 0.5%)
# TP: OR at 13.60. Buy: 13.42
# TP: OR at 13.60. Buy: 13.42
# TP: OR at 13.60. Buy: 13.42
# TP: OR at 13.60. Buy: 13.42
# BUY GPSC at 39.50. Dip triggered (Price < EMA - 0.5%)
# BUY OR at 13.40. Dip triggered (Price < EMA - 0.5%)
# BUY RATCH at 28.00. Dip triggered (Price < EMA - 0.5%)
# TP: TLI at 10.40. Buy: 10.32
# TP: TLI at 10.40. Buy: 10.32
# TP: TLI at 10.40. Buy: 10.32
# TP: TLI at 10.40. Buy: 10.32
# BUY RATCH at 28.00. Dip triggered (Price < EMA - 0.5%)
# TP: TIDLOR at 21.50. Buy: 21.34
# TP: TIDLOR at 21.50. Buy: 21.34
# TP: TIDLOR at 21.50. Buy: 21.34
# SL: COM7 at 26.00. Buy: 26.79
# SL: COM7 at 26.00. Buy: 26.79
# SL: COM7 at 26.00. Buy: 26.79
# SL: COM7 at 26.00. Buy: 26.79
# SL: COM7 at 26.00. Buy: 26.79
# BUY KTC at 30.50. Dip triggered (Price < EMA - 0.5%)
# TP: TIDLOR at 21.50. Buy: 21.34
# TP: TRUE at 11.30. Buy: 11.22
# TP: TRUE at 11.30. Buy: 11.22
# TP: TRUE at 11.30. Buy: 11.22
# TP: TRUE at 11.30. Buy: 11.22
# TP: TRUE at 11.30. Buy: 11.22
# BUY COM7 at 26.00. Dip triggered (Price < EMA - 0.5%)
# BUY RATCH at 27.50. Dip triggered (Price < EMA - 0.5%)
# SL: RATCH at 27.50. Buy: 28.30
# SL: RATCH at 27.50. Buy: 28.30
# TP: COM7 at 26.75. Buy: 26.29
# BUY RATCH at 27.75. Dip triggered (Price < EMA - 0.5%)
# BUY RATCH at 27.75. Dip triggered (Price < EMA - 0.5%)
# TP: RATCH at 28.25. Buy: 27.80
# TP: RATCH at 28.25. Buy: 28.05
# TP: RATCH at 28.25. Buy: 28.05
# TP: RATCH at 28.25. Buy: 28.05
# TP: TLI at 10.40. Buy: 10.32
# TP: TLI at 10.40. Buy: 10.32
# TP: TRUE at 11.30. Buy: 11.22
# TP: TRUE at 11.30. Buy: 11.22
# TP: TLI at 10.40. Buy: 10.32
# BUY AOT at 40.00. Dip triggered (Price < EMA - 0.5%)
# BUY BEM at 5.05. Dip triggered (Price < EMA - 0.5%)
# BUY COM7 at 26.50. Dip triggered (Price < EMA - 0.5%)
# TP: TOP at 34.50. Buy: 34.06
# TP: TOP at 34.50. Buy: 34.06
# TP: TOP at 34.50. Buy: 34.06
# TP: TOP at 34.50. Buy: 34.06
# TP: TOP at 34.50. Buy: 34.06
# BUY COM7 at 26.50. Dip triggered (Price < EMA - 0.5%)
# TP: TOP at 34.50. Buy: 34.06
# TP: TOP at 34.50. Buy: 34.06
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: TOP at 34.50. Buy: 34.06
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# BUY BEM at 5.05. Dip triggered (Price < EMA - 0.5%)
# BUY VGI at 1.36. Dip triggered (Price < EMA - 0.5%)
# BUY COM7 at 26.50. Dip triggered (Price < EMA - 0.5%)
# BUY TOP at 34.00. Dip triggered (Price < EMA - 0.5%)
# TP: BEM at 5.15. Buy: 5.11
# TP: BEM at 5.15. Buy: 5.11
# TP: BEM at 5.15. Buy: 5.11
# TP: BEM at 5.15. Buy: 5.11
# TP: BEM at 5.15. Buy: 5.11
# BUY COM7 at 26.50. Dip triggered (Price < EMA - 0.5%)
# BUY BEM at 5.05. Dip triggered (Price < EMA - 0.5%)
# BUY BEM at 5.05. Dip triggered (Price < EMA - 0.5%)
# TP: CBG at 51.25. Buy: 50.84
# TP: CBG at 51.25. Buy: 50.84
# BUY COM7 at 26.50. Dip triggered (Price < EMA - 0.5%)
# BUY BEM at 5.05. Dip triggered (Price < EMA - 0.5%)
# TP: AWC at 2.12. Buy: 2.10
# TP: CCET at 5.85. Buy: 5.81
# TP: CCET at 5.85. Buy: 5.81
# TP: CCET at 5.85. Buy: 5.81
# TP: CCET at 5.85. Buy: 5.81
# TP: CCET at 5.85. Buy: 5.81
# BUY TRUE at 11.10. Dip triggered (Price < EMA - 0.5%)
# TP: CCET at 5.85. Buy: 5.81
# TP: CCET at 5.85. Buy: 5.81
# BUY TRUE at 11.10. Dip triggered (Price < EMA - 0.5%)
# TP: CCET at 5.85. Buy: 5.81
# BUY TLI at 10.30. Dip triggered (Price < EMA - 0.5%)
# BUY TRUE at 11.10. Dip triggered (Price < EMA - 0.5%)
# TP: CPALL at 48.00. Buy: 47.58
# BUY TRUE at 11.10. Dip triggered (Price < EMA - 0.5%)
# BUY OR at 13.30. Dip triggered (Price < EMA - 0.5%)
# TP: BH at 175.00. Buy: 173.79
# BUY TLI at 10.30. Dip triggered (Price < EMA - 0.5%)
# BUY RATCH at 28.00. Dip triggered (Price < EMA - 0.5%)
# BUY RATCH at 28.00. Dip triggered (Price < EMA - 0.5%)
# BUY TLI at 10.30. Dip triggered (Price < EMA - 0.5%)
# BUY RATCH at 28.00. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.75. Dip triggered (Price < EMA - 0.5%)
# BUY VGI at 1.36. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.08. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.75. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.75. Dip triggered (Price < EMA - 0.5%)
# BUY RATCH at 28.00. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.08. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.08. Dip triggered (Price < EMA - 0.5%)
# BUY TOP at 34.00. Dip triggered (Price < EMA - 0.5%)
# BUY TLI at 10.30. Dip triggered (Price < EMA - 0.5%)
# BUY TLI at 10.30. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.75. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.08. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.08. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.75. Dip triggered (Price < EMA - 0.5%)
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# BUY MTC at 40.00. Dip triggered (Price < EMA - 0.5%)
# BUY MTC at 40.00. Dip triggered (Price < EMA - 0.5%)
# BUY TOP at 34.00. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.08. Dip triggered (Price < EMA - 0.5%)
# BUY RATCH at 28.00. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.08. Dip triggered (Price < EMA - 0.5%)
# BUY BANPU at 4.38. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.08. Dip triggered (Price < EMA - 0.5%)
# BUY BH at 174.00. Dip triggered (Price < EMA - 0.5%)
# BUY AOT at 39.75. Dip triggered (Price < EMA - 0.5%)
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# BUY CPALL at 47.50. Dip triggered (Price < EMA - 0.5%)
# TP: CBG at 51.25. Buy: 50.84
# BUY TOP at 34.25. Dip triggered (Price < EMA - 0.5%)
# BUY BCP at 29.25. Dip triggered (Price < EMA - 0.5%)
# BUY BCP at 29.25. Dip triggered (Price < EMA - 0.5%)
# BUY TOP at 34.00. Dip triggered (Price < EMA - 0.5%)
# BUY HMPRO at 7.10. Dip triggered (Price < EMA - 0.5%)
# BUY BCP at 29.25. Dip triggered (Price < EMA - 0.5%)
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# BUY BCP at 29.25. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.08. Dip triggered (Price < EMA - 0.5%)
# BUY PTTGC at 25.00. Dip triggered (Price < EMA - 0.5%)
# BUY PTTGC at 25.00. Dip triggered (Price < EMA - 0.5%)
# BUY PTTGC at 24.90. Dip triggered (Price < EMA - 0.5%)
# BUY BCP at 29.25. Dip triggered (Price < EMA - 0.5%)
# BUY TIDLOR at 21.40. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.08. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.08. Dip triggered (Price < EMA - 0.5%)
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# BUY AWC at 2.08. Dip triggered (Price < EMA - 0.5%)
# BUY HMPRO at 7.10. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.08. Dip triggered (Price < EMA - 0.5%)
# TP: MTC at 40.75. Buy: 40.32
# TP: MTC at 40.75. Buy: 40.32
# TP: MTC at 40.75. Buy: 40.32
# TP: MTC at 40.75. Buy: 40.32
# TP: MTC at 40.75. Buy: 40.32
# TP: MTC at 40.75. Buy: 40.32
# TP: MTC at 40.75. Buy: 40.32
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# BUY KKP at 62.00. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.08. Dip triggered (Price < EMA - 0.5%)
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# BUY AWC at 2.08. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.08. Dip triggered (Price < EMA - 0.5%)
# BUY BCP at 29.25. Dip triggered (Price < EMA - 0.5%)
# BUY BCP at 29.25. Dip triggered (Price < EMA - 0.5%)
# BUY CPN at 54.75. Dip triggered (Price < EMA - 0.5%)
# TP: CPN at 55.50. Buy: 55.09
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: PTTGC at 25.25. Buy: 25.04
# BUY AWC at 2.08. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.08. Dip triggered (Price < EMA - 0.5%)
# TP: GPSC at 40.25. Buy: 39.82
# BUY AWC at 2.08. Dip triggered (Price < EMA - 0.5%)
# TP: GPSC at 40.25. Buy: 39.82
# TP: GPSC at 40.25. Buy: 39.82
# TP: GPSC at 40.25. Buy: 39.82
# TP: BEM at 5.15. Buy: 5.11
# TP: BEM at 5.15. Buy: 5.11
# TP: BEM at 5.15. Buy: 5.11
# TP: BEM at 5.15. Buy: 5.11
# TP: BEM at 5.15. Buy: 5.11
# TP: GPSC at 40.25. Buy: 39.82
# BUY BEM at 5.05. Dip triggered (Price < EMA - 0.5%)
# SL: VGI at 1.35. Buy: 1.39
# TP: PTTGC at 25.25. Buy: 25.04
# BUY VGI at 1.35. Dip triggered (Price < EMA - 0.5%)
# TP: PTTGC at 25.25. Buy: 25.04
# BUY PTTGC at 24.90. Dip triggered (Price < EMA - 0.5%)
# TP: COM7 at 27.00. Buy: 26.79
# TP: COM7 at 27.00. Buy: 26.79
# TP: COM7 at 27.00. Buy: 26.79
# TP: COM7 at 27.00. Buy: 26.79
# TP: COM7 at 27.00. Buy: 26.79
# TP: COM7 at 27.00. Buy: 26.79
# TP: COM7 at 27.00. Buy: 26.79
# BUY AWC at 2.08. Dip triggered (Price < EMA - 0.5%)
# TP: OR at 13.60. Buy: 13.42
# TP: OR at 13.60. Buy: 13.42
# TP: OR at 13.60. Buy: 13.42
# TP: OR at 13.60. Buy: 13.42
# TP: OR at 13.60. Buy: 13.42
# TP: OR at 13.60. Buy: 13.42
# TP: COM7 at 27.00. Buy: 26.79
# BUY COM7 at 26.50. Dip triggered (Price < EMA - 0.5%)
# TP: COM7 at 27.00. Buy: 26.79
# BUY COM7 at 26.75. Dip triggered (Price < EMA - 0.5%)
# BUY HMPRO at 7.10. Dip triggered (Price < EMA - 0.5%)
# BUY HMPRO at 7.10. Dip triggered (Price < EMA - 0.5%)
# BUY TIDLOR at 21.40. Dip triggered (Price < EMA - 0.5%)
# BUY TCAP at 50.50. Dip triggered (Price < EMA - 0.5%)
# BUY TCAP at 50.50. Dip triggered (Price < EMA - 0.5%)
# BUY TIDLOR at 21.40. Dip triggered (Price < EMA - 0.5%)
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: KKP at 62.75. Buy: 62.35
# BUY BEM at 5.05. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.08. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.08. Dip triggered (Price < EMA - 0.5%)
# BUY TIDLOR at 21.40. Dip triggered (Price < EMA - 0.5%)
# BUY SCGP at 17.40. Dip triggered (Price < EMA - 0.5%)
# TP: AOT at 40.50. Buy: 40.07
# BUY SCGP at 17.40. Dip triggered (Price < EMA - 0.5%)
# BUY COM7 at 26.50. Dip triggered (Price < EMA - 0.5%)
# BUY COM7 at 26.50. Dip triggered (Price < EMA - 0.5%)
# BUY BEM at 5.05. Dip triggered (Price < EMA - 0.5%)
# TP: CCET at 5.85. Buy: 5.81
# TP: CCET at 5.85. Buy: 5.81
# TP: CCET at 5.85. Buy: 5.81
# TP: CCET at 5.85. Buy: 5.81
# TP: CCET at 5.85. Buy: 5.81
# TP: CCET at 5.85. Buy: 5.81
# TP: CCET at 5.85. Buy: 5.81
# BUY TIDLOR at 21.40. Dip triggered (Price < EMA - 0.5%)
# TP: CCET at 5.85. Buy: 5.81
# BUY COM7 at 26.50. Dip triggered (Price < EMA - 0.5%)
# BUY COM7 at 26.50. Dip triggered (Price < EMA - 0.5%)
# BUY PTTGC at 24.60. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.08. Dip triggered (Price < EMA - 0.5%)
# BUY WHA at 3.62. Dip triggered (Price < EMA - 0.5%)
# TP: BBL at 153.50. Buy: 152.26
# BUY TCAP at 50.50. Dip triggered (Price < EMA - 0.5%)
# BUY TCAP at 50.50. Dip triggered (Price < EMA - 0.5%)
# TP: AOT at 40.50. Buy: 40.07
# BUY LH at 4.10. Dip triggered (Price < EMA - 0.5%)
# TP: AOT at 40.50. Buy: 40.07
# BUY OSP at 16.30. Dip triggered (Price < EMA - 0.5%)
# BUY AOT at 40.00. Dip triggered (Price < EMA - 0.5%)
# TP: TIDLOR at 21.70. Buy: 21.54
# TP: TIDLOR at 21.70. Buy: 21.54
# TP: TIDLOR at 21.70. Buy: 21.54
# TP: TIDLOR at 21.70. Buy: 21.54
# TP: TIDLOR at 21.70. Buy: 21.54
# TP: TIDLOR at 21.70. Buy: 21.54
# TP: TIDLOR at 21.70. Buy: 21.54
# TP: AOT at 40.50. Buy: 40.07
# TP: TIDLOR at 21.70. Buy: 21.54
# BUY AOT at 40.00. Dip triggered (Price < EMA - 0.5%)
# TP: BEM at 5.15. Buy: 5.11
# TP: BEM at 5.15. Buy: 5.11
# TP: BEM at 5.15. Buy: 5.11
# TP: BEM at 5.15. Buy: 5.11
# TP: BEM at 5.15. Buy: 5.11
# BUY BEM at 5.05. Dip triggered (Price < EMA - 0.5%)
# BUY OR at 13.40. Dip triggered (Price < EMA - 0.5%)
# BUY BEM at 5.05. Dip triggered (Price < EMA - 0.5%)
# BUY OR at 13.40. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.08. Dip triggered (Price < EMA - 0.5%)
# BUY TIDLOR at 21.50. Dip triggered (Price < EMA - 0.5%)
# BUY BEM at 5.05. Dip triggered (Price < EMA - 0.5%)
# BUY IVL at 20.50. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.80. Dip triggered (Price < EMA - 0.5%)
# BUY OR at 13.40. Dip triggered (Price < EMA - 0.5%)
# TP: CCET at 5.90. Buy: 5.86
# TP: BH at 176.00. Buy: 174.79
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: BCP at 29.75. Buy: 29.55
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# BUY AWC at 2.10. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.10. Dip triggered (Price < EMA - 0.5%)
# TP: RATCH at 28.50. Buy: 28.30
# TP: RATCH at 28.50. Buy: 28.30
# TP: RATCH at 28.50. Buy: 28.30
# TP: RATCH at 28.50. Buy: 28.30
# TP: RATCH at 28.50. Buy: 28.30
# TP: RATCH at 28.50. Buy: 28.30
# TP: RATCH at 28.50. Buy: 28.30
# BUY AWC at 2.10. Dip triggered (Price < EMA - 0.5%)
# BUY PTTGC at 24.50. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.10. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.10. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.80. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.80. Dip triggered (Price < EMA - 0.5%)
# TP: SCGP at 17.70. Buy: 17.53
# TP: SCGP at 17.70. Buy: 17.53
# TP: SCGP at 17.70. Buy: 17.53
# TP: KTC at 31.00. Buy: 30.80
# TP: KTC at 31.00. Buy: 30.80
# TP: KTC at 31.00. Buy: 30.80
# TP: KTC at 31.00. Buy: 30.80
# TP: KTC at 31.00. Buy: 30.80
# BUY SCGP at 17.40. Dip triggered (Price < EMA - 0.5%)
# BUY SCGP at 17.40. Dip triggered (Price < EMA - 0.5%)
# TP: KTC at 31.00. Buy: 30.80
# TP: KTC at 31.00. Buy: 30.80
# SL: VGI at 1.34. Buy: 1.38
# SL: VGI at 1.34. Buy: 1.38
# TP: KTC at 31.00. Buy: 30.80
# TP: SCGP at 17.90. Buy: 17.53
# TP: SCGP at 17.90. Buy: 17.53
# TP: SCGP at 17.90. Buy: 17.53
# BUY SCGP at 17.40. Dip triggered (Price < EMA - 0.5%)
# BUY SCGP at 17.40. Dip triggered (Price < EMA - 0.5%)
# BUY SCGP at 17.40. Dip triggered (Price < EMA - 0.5%)
# BUY SCGP at 17.40. Dip triggered (Price < EMA - 0.5%)
# BUY SCGP at 17.40. Dip triggered (Price < EMA - 0.5%)
# TP: CCET at 5.90. Buy: 5.86
# TP: CCET at 5.90. Buy: 5.86
# TP: CCET at 5.90. Buy: 5.86
# BUY OSP at 16.20. Dip triggered (Price < EMA - 0.5%)
# BUY OSP at 16.20. Dip triggered (Price < EMA - 0.5%)
# BUY OSP at 16.20. Dip triggered (Price < EMA - 0.5%)
# BUY KTC at 30.75. Dip triggered (Price < EMA - 0.5%)
# BUY CPN at 54.50. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.85. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.85. Dip triggered (Price < EMA - 0.5%)
# BUY KTC at 30.75. Dip triggered (Price < EMA - 0.5%)
# BUY KTC at 30.75. Dip triggered (Price < EMA - 0.5%)
# BUY KTC at 30.75. Dip triggered (Price < EMA - 0.5%)
# TP: GULF at 44.50. Buy: 44.07
# SL: COM7 at 26.25. Buy: 27.05
# BUY RATCH at 28.00. Dip triggered (Price < EMA - 0.5%)
# BUY RATCH at 28.00. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.85. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.85. Dip triggered (Price < EMA - 0.5%)
# BUY RATCH at 28.00. Dip triggered (Price < EMA - 0.5%)
# BUY OR at 13.40. Dip triggered (Price < EMA - 0.5%)
# BUY BCP at 29.00. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.85. Dip triggered (Price < EMA - 0.5%)
# BUY OR at 13.40. Dip triggered (Price < EMA - 0.5%)
# BUY VGI at 1.34. Dip triggered (Price < EMA - 0.5%)
# BUY BCP at 29.00. Dip triggered (Price < EMA - 0.5%)
# TP: CPN at 55.25. Buy: 54.84
# TP: BCP at 29.50. Buy: 29.30
# TP: BCP at 29.50. Buy: 29.30
# BUY COM7 at 26.50. Dip triggered (Price < EMA - 0.5%)
# BUY BCP at 29.00. Dip triggered (Price < EMA - 0.5%)
# BUY RATCH at 28.00. Dip triggered (Price < EMA - 0.5%)
# TP: EGCO at 138.50. Buy: 137.23
# BUY BCP at 29.00. Dip triggered (Price < EMA - 0.5%)
# BUY MINT at 22.40. Dip triggered (Price < EMA - 0.5%)
# TP: RATCH at 29.50. Buy: 28.30
# TP: RATCH at 29.50. Buy: 28.30
# TP: RATCH at 29.50. Buy: 28.30
# TP: RATCH at 29.50. Buy: 28.30
# TP: RATCH at 29.50. Buy: 28.30
# BUY MINT at 22.40. Dip triggered (Price < EMA - 0.5%)
# BUY KTC at 30.75. Dip triggered (Price < EMA - 0.5%)
# SL: PTTGC at 24.30. Buy: 25.04
# BUY VGI at 1.34. Dip triggered (Price < EMA - 0.5%)
# BUY LH at 4.08. Dip triggered (Price < EMA - 0.5%)
# TP: BCP at 29.50. Buy: 29.30
# TP: BCP at 29.50. Buy: 29.30
# TP: BCP at 29.50. Buy: 29.30
# TP: BCP at 29.50. Buy: 29.30
# TP: AOT at 40.75. Buy: 40.32
# TP: AOT at 40.75. Buy: 40.32
# TP: AOT at 40.75. Buy: 40.32
# BUY BCP at 29.00. Dip triggered (Price < EMA - 0.5%)
# BUY BCP at 29.00. Dip triggered (Price < EMA - 0.5%)
# SL: VGI at 1.33. Buy: 1.37
# SL: VGI at 1.33. Buy: 1.37
# TP: TOP at 34.75. Buy: 34.31
# TP: TOP at 34.75. Buy: 34.31
# TP: TOP at 34.75. Buy: 34.31
# TP: TOP at 34.75. Buy: 34.31
# TP: OR at 13.70. Buy: 13.52
# TP: OR at 13.70. Buy: 13.52
# TP: OR at 13.70. Buy: 13.52
# TP: OR at 13.70. Buy: 13.52
# TP: OR at 13.70. Buy: 13.52
# TP: TOP at 34.75. Buy: 34.31
# TP: TOP at 34.75. Buy: 34.31
# TP: OR at 13.70. Buy: 13.52
# TP: OR at 13.70. Buy: 13.52
# TP: OR at 13.70. Buy: 13.52
# TP: TOP at 34.75. Buy: 34.31
# TP: TOP at 34.75. Buy: 34.31
# BUY OR at 13.60. Dip triggered (Price < EMA - 0.5%)
# BUY OR at 13.50. Dip triggered (Price < EMA - 0.5%)
# BUY VGI at 1.33. Dip triggered (Price < EMA - 0.5%)
# BUY OR at 13.50. Dip triggered (Price < EMA - 0.5%)
# BUY TIDLOR at 21.50. Dip triggered (Price < EMA - 0.5%)
# BUY TIDLOR at 21.50. Dip triggered (Price < EMA - 0.5%)
# BUY LH at 4.08. Dip triggered (Price < EMA - 0.5%)
# BUY OR at 13.50. Dip triggered (Price < EMA - 0.5%)
# BUY VGI at 1.33. Dip triggered (Price < EMA - 0.5%)
# BUY CRC at 20.50. Dip triggered (Price < EMA - 0.5%)
# SL: CCET at 5.75. Buy: 5.91
# SL: CCET at 5.75. Buy: 5.91
# SL: CCET at 5.75. Buy: 5.91
# SL: CCET at 5.75. Buy: 5.91
# SL: CCET at 5.75. Buy: 5.91
# BUY CCET at 5.75. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.75. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.75. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.75. Dip triggered (Price < EMA - 0.5%)
# TP: CCET at 5.85. Buy: 5.81
# TP: CCET at 5.85. Buy: 5.81
# TP: CCET at 5.85. Buy: 5.81
# TP: CCET at 5.85. Buy: 5.81
# TP: CCET at 5.85. Buy: 5.81
# TP: CCET at 5.85. Buy: 5.81
# TP: CCET at 5.85. Buy: 5.81
# TP: AWC at 2.14. Buy: 2.12
# TP: AWC at 2.14. Buy: 2.12
# TP: AWC at 2.14. Buy: 2.12
# TP: AWC at 2.14. Buy: 2.12
# TP: AWC at 2.14. Buy: 2.12
# TP: AWC at 2.52. Buy: 2.12
# TP: AWC at 2.52. Buy: 2.12
# BUY AWC at 2.12. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.12. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.12. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.12. Dip triggered (Price < EMA - 0.5%)
# SL: AWC at 2.08. Buy: 2.14
# SL: AWC at 2.08. Buy: 2.14
# SL: AWC at 2.08. Buy: 2.14
# SL: AWC at 2.08. Buy: 2.14
# BUY AWC at 2.10. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.10. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.08. Dip triggered (Price < EMA - 0.5%)
# SL: AWC at 2.08. Buy: 2.14
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# TP: AWC at 2.12. Buy: 2.10
# BUY CCET at 5.85. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.10. Dip triggered (Price < EMA - 0.5%)
# BUY OR at 13.60. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.80. Dip triggered (Price < EMA - 0.5%)
# TP: LH at 4.20. Buy: 4.13
# TP: LH at 4.20. Buy: 4.11
# TP: LH at 4.20. Buy: 4.11
# BUY LH at 4.08. Dip triggered (Price < EMA - 0.5%)
# BUY LH at 4.08. Dip triggered (Price < EMA - 0.5%)
# TP: TIDLOR at 21.80. Buy: 21.64
# TP: TIDLOR at 21.80. Buy: 21.64
# TP: TIDLOR at 21.80. Buy: 21.64
# TP: TIDLOR at 21.80. Buy: 21.64
# BUY AWC at 2.10. Dip triggered (Price < EMA - 0.5%)
# TP: CCET at 5.90. Buy: 5.86
# BUY AWC at 2.10. Dip triggered (Price < EMA - 0.5%)
# TP: CCET at 5.90. Buy: 5.86
# BUY AWC at 2.10. Dip triggered (Price < EMA - 0.5%)
# TP: CRC at 20.80. Buy: 20.63
# BUY AWC at 2.10. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.85. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.85. Dip triggered (Price < EMA - 0.5%)
# BUY TIDLOR at 21.60. Dip triggered (Price < EMA - 0.5%)
# BUY TIDLOR at 21.60. Dip triggered (Price < EMA - 0.5%)
# BUY BANPU at 4.36. Dip triggered (Price < EMA - 0.5%)
# BUY TIDLOR at 21.60. Dip triggered (Price < EMA - 0.5%)
# TP: AWC at 2.14. Buy: 2.12
# TP: AWC at 2.14. Buy: 2.12
# TP: AWC at 2.14. Buy: 2.12
# TP: AWC at 2.14. Buy: 2.12
# TP: AWC at 2.14. Buy: 2.12
# BUY AWC at 2.10. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.10. Dip triggered (Price < EMA - 0.5%)
# TP: AWC at 2.52. Buy: 2.12
# TP: AWC at 2.52. Buy: 2.12
# TP: AWC at 2.52. Buy: 2.12
# TP: AWC at 2.52. Buy: 2.12
# BUY AWC at 2.10. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.10. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.12. Dip triggered (Price < EMA - 0.5%)
# TP: AWC at 2.70. Buy: 2.12
# TP: AWC at 2.70. Buy: 2.12
# TP: AWC at 2.70. Buy: 2.12
# TP: AWC at 2.70. Buy: 2.12
# TP: AWC at 2.70. Buy: 2.14
# BUY AWC at 2.12. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.16. Dip triggered (Price < EMA - 0.5%)
# TP: AWC at 2.16. Buy: 2.12
# TP: AWC at 2.16. Buy: 2.14
# TP: AWC at 2.16. Buy: 2.14
# BUY AWC at 2.12. Dip triggered (Price < EMA - 0.5%)
# SL: AWC at 2.12. Buy: 2.18
# BUY AWC at 2.12. Dip triggered (Price < EMA - 0.5%)
# SL: AWC at 2.12. Buy: 2.18
# BUY AWC at 2.12. Dip triggered (Price < EMA - 0.5%)
# SL: AWC at 2.12. Buy: 2.18
# BUY AWC at 2.12. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.10. Dip triggered (Price < EMA - 0.5%)
# BUY TIDLOR at 21.60. Dip triggered (Price < EMA - 0.5%)
# BUY CCET at 5.85. Dip triggered (Price < EMA - 0.5%)
# TP: TIDLOR at 21.90. Buy: 21.74
# TP: TIDLOR at 21.90. Buy: 21.74
# TP: TIDLOR at 21.90. Buy: 21.74
# TP: TIDLOR at 21.90. Buy: 21.74
# BUY TOP at 34.50. Dip triggered (Price < EMA - 0.5%)
# TP: TIDLOR at 21.90. Buy: 21.74
# TP: TIDLOR at 21.90. Buy: 21.74
# BUY CCET at 5.85. Dip triggered (Price < EMA - 0.5%)
# TP: TIDLOR at 21.90. Buy: 21.74
# BUY CCET at 5.85. Dip triggered (Price < EMA - 0.5%)
# BUY SCC at 203.00. Dip triggered (Price < EMA - 0.5%)
# TP: AWC at 2.14. Buy: 2.12
# BUY AWC at 2.10. Dip triggered (Price < EMA - 0.5%)
# BUY TIDLOR at 21.70. Dip triggered (Price < EMA - 0.5%)
# TP: AWC at 2.14. Buy: 2.12
# TP: AWC at 2.14. Buy: 2.12
# TP: AWC at 2.14. Buy: 2.12
# TP: AWC at 2.14. Buy: 2.12
# TP: AWC at 2.70. Buy: 2.14
# TP: AWC at 2.70. Buy: 2.12
# TP: AWC at 2.70. Buy: 2.12
# BUY AWC at 2.10. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.12. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.12. Dip triggered (Price < EMA - 0.5%)
# BUY AWC at 2.10. Dip triggered (Price < EMA - 0.5%)
# BUY EGCO at 137.00. Dip triggered (Price < EMA - 0.5%)
# SL: BTS at 2.82. Buy: 2.90
# SL: BTS at 2.82. Buy: 2.90
# SL: BTS at 2.82. Buy: 2.90
# SL: BTS at 2.82. Buy: 2.90
# SL: BTS at 2.82. Buy: 2.90
# BUY GPSC at 40.25. Dip triggered (Price < EMA - 0.5%)
# BUY BTS at 2.84. Dip triggered (Price < EMA - 0.5%)
# BUY KTB at 25.00. Dip triggered (Price < EMA - 0.5%)
# BUY KTB at 25.00. Dip triggered (Price < EMA - 0.5%)
# BUY KTB at 25.00. Dip triggered (Price < EMA - 0.5%)
# BUY TIDLOR at 21.70. Dip triggered (Price < EMA - 0.5%)
# BUY TIDLOR at 21.70. Dip triggered (Price < EMA - 0.5%)
# TP: TIDLOR at 22.00. Buy: 21.84
# TP: TIDLOR at 22.00. Buy: 21.84
# TP: TIDLOR at 22.00. Buy: 21.84
# TP: TIDLOR at 22.00. Buy: 21.84
# BUY KTB at 25.00. Dip triggered (Price < EMA - 0.5%)
# BUY KTB at 25.00. Dip triggered (Price < EMA - 0.5%)
# BUY BTS at 2.82. Dip triggered (Price < EMA - 0.5%)
# BUY BTS at 2.82. Dip triggered (Price < EMA - 0.5%)
# BUY BTS at 2.82. Dip triggered (Price < EMA - 0.5%)
# BUY TIDLOR at 21.70. Dip triggered (Price < EMA - 0.5%)
# BUY TIDLOR at 21.70. Dip triggered (Price < EMA - 0.5%)
# TP: TIDLOR at 22.00. Buy: 21.84
# TP: TIDLOR at 22.00. Buy: 21.84
# TP: WHA at 3.68. Buy: 3.65
# BUY BTS at 2.82. Dip triggered (Price < EMA - 0.5%)
# BUY KKP at 62.75. Dip triggered (Price < EMA - 0.5%)
# TP: TIDLOR at 22.00. Buy: 21.84
# BUY TIDLOR at 21.70. Dip triggered (Price < EMA - 0.5%)
# BUY TIDLOR at 21.70. Dip triggered (Price < EMA - 0.5%)
# BUY TIDLOR at 21.70. Dip triggered (Price < EMA - 0.5%)
# TP: TIDLOR at 22.00. Buy: 21.84
# TP: TIDLOR at 22.00. Buy: 21.84
# TP: TIDLOR at 22.00. Buy: 21.84
# TP: TIDLOR at 22.00. Buy: 21.84
# TP: GPSC at 41.00. Buy: 40.57
# BUY AOT at 40.50. Dip triggered (Price < EMA - 0.5%)
# BUY AOT at 40.50. Dip triggered (Price < EMA - 0.5%)
# BUY TIDLOR at 21.80. Dip triggered (Price < EMA - 0.5%)
# BUY SCC at 200.00. Dip triggered (Price < EMA - 0.5%)
# TP: KKP at 63.50. Buy: 63.11
# BUY AOT at 40.50. Dip triggered (Price < EMA - 0.5%)
# BUY TOP at 34.75. Dip triggered (Price < EMA - 0.5%)
# BUY TIDLOR at 21.70. Dip triggered (Price < EMA - 0.5%)
# TP: OR at 13.80. Buy: 13.62
# TP: OR at 13.80. Buy: 13.62
# TP: OR at 13.80. Buy: 13.62
# TP: OR at 13.80. Buy: 13.62
# TP: OR at 13.80. Buy: 13.62
# TP: OR at 13.80. Buy: 13.62
# BUY TOP at 34.75. Dip triggered (Price < EMA - 0.5%)
# TP: TIDLOR at 22.00. Buy: 21.84
# TP: TIDLOR at 22.00. Buy: 21.84
# TP: TOP at 35.25. Buy: 34.81
# BUY OR at 13.70. Dip triggered (Price < EMA - 0.5%)
# TP: LH at 4.16. Buy: 4.11
# TP: LH at 4.16. Buy: 4.11
# TP: LH at 4.16. Buy: 4.11
# BUY GULF at 44.00. Dip triggered (Price < EMA - 0.5%)
# BUY OR at 13.70. Dip triggered (Price < EMA - 0.5%)
# BUY OR at 13.70. Dip triggered (Price < EMA - 0.5%)
# BUY TIDLOR at 21.80. Dip triggered (Price < EMA - 0.5%)
# BUY OR at 13.70. Dip triggered (Price < EMA - 0.5%)
# BUY TOP at 35.00. Dip triggered (Price < EMA - 0.5%)
# SL: VGI at 1.32. Buy: 1.36
# BUY VGI at 1.32. Dip triggered (Price < EMA - 0.5%)
# BUY TOP at 35.00. Dip triggered (Price < EMA - 0.5%)
# TP: TIDLOR at 22.10. Buy: 21.94
# BUY TIDLOR at 21.90. Dip triggered (Price < EMA - 0.5%)
# BUY KKP at 63.25. Dip triggered (Price < EMA - 0.5%)
# BUY TOP at 35.00. Dip triggered (Price < EMA - 0.5%)
# BUY AOT at 40.50. Dip triggered (Price < EMA - 0.5%)
# BUY AOT at 40.50. Dip triggered (Price < EMA - 0.5%)
# BUY TIDLOR at 21.90. Dip triggered (Price < EMA - 0.5%)
# BUY TIDLOR at 21.90. Dip triggered (Price < EMA - 0.5%)
# TP: LH at 4.16. Buy: 4.11
# BUY LH at 4.08. Dip triggered (Price < EMA - 0.5%)
# BUY TIDLOR at 21.80. Dip triggered (Price < EMA - 0.5%)
# TP: KKP at 64.00. Buy: 63.61
# TP: TIDLOR at 22.10. Buy: 21.94
# TP: TIDLOR at 22.10. Buy: 21.94
# TP: TIDLOR at 22.10. Buy: 21.94
# TP: TIDLOR at 22.10. Buy: 21.94
# BUY PTTEP at 108.50. Dip triggered (Price < EMA - 0.5%)
# TP: SCC at 203.00. Buy: 201.34
# TP: SCC at 203.00. Buy: 201.34
# BUY DELTA at 183.50. Dip triggered (Price < EMA - 0.5%)
# BUY TIDLOR at 21.90. Dip triggered (Price < EMA - 0.5%)
# TP: DELTA at 185.50. Buy: 184.31
# TP: LH at 4.14. Buy: 4.11
# BUY LH at 4.06. Dip triggered (Price < EMA - 0.5%)
# ✅ Summary saved to /Users/pun/Downloads/tradeSim_0.1.6/result/YokAndPun/YokAndPun_portfolios_transaction_summary.csv

# %% [markdown]
# ### **Examine Portfolio Information**
#
# You can view portfolio statistics using the provided methods.
#
# For example:
# ```
# strategy_runner.get_all_stock_info() -> Returns a summary of each stock in the portfolio.
# strategy_runner.get_portfolio_info() -> Returns a summary of portfolio details such as cash balance, NAV, and ROI.
# ```
# Full documentation is available in the provided PDF.

# %%
portInfo = strategy_runner.get_portfolio_info()
stockInfo = strategy_runner.get_all_stocks_info()
pd.DataFrame([portInfo]).T
# Out:
#                                   0
# Owner                     YokAndPun
# Number of Stocks                120
# Total Cost                241810.54
# Unrealized P&L             -1725.54
# Unrealized %                  -0.71
# Realized P&L              -99883.36
# Cash Balance             9658306.11
# Net Asset Value          9898391.11
# Max NAV                  9902490.05
# Min NAV                   9878189.1
# Max Drawdown (%)              -0.35
# Relative Drawdown              -0.0
# Calmar Ratio               2.922984
# Previous Day Max DD (%)       -0.35
# Number of Wins                 1883
# Number of Sells                6846
# Win Rate                  27.505112
# Return rate               -1.016089

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000) 
pd.set_option('display.max_rows', None)

df = pd.DataFrame(stockInfo)
print(df)
# Out:
#     Symbol  Buy Price  Actual Volume  Average Cost  Market Price  Amount Cost  Market Value  Unrealized P&L  Unrealized %  Realized P&L             Buy time
# 0      TTB       1.86            500        1.8671          1.84       933.55         920.0          -13.55     -1.451449           0.0  2025-10-06 14:28:00
# 1      PTT      31.55            500       31.7533         31.25     15876.65       15625.0         -251.65     -1.585032           0.0  2025-10-14 09:57:24
# 2      CPF      22.54            100       22.5378         22.20      2253.78        2220.0          -33.78     -1.498815           0.0  2025-10-14 10:28:57
# 3       TU      13.42            500       13.3624         13.10      6681.20        6550.0         -131.20     -1.963719           0.0  2025-10-14 15:09:44
# 4    HMPRO       7.16            500        7.1620          7.15      3581.00        3575.0           -6.00     -0.167551           0.0  2025-10-15 11:46:03
# 5     TRUE      11.22            500       11.2188         11.10      5609.40        5550.0          -59.40     -1.058937           0.0  2025-10-15 10:35:41
# 6    CPALL      47.83            100       47.8302         47.25      4783.02        4725.0          -58.02     -1.213041           0.0  2025-10-15 10:33:47
# 7      OSP      16.33            500       16.3875         16.30      8193.75        8150.0          -43.75     -0.533944           0.0  2025-10-15 15:53:05
# 8    PTTGC      24.64            200       24.6914         24.60      4938.28        4920.0          -18.28     -0.370169           0.0  2025-10-15 11:11:06
# 9    BANPU       4.39            200        4.3974          4.32       879.48         864.0          -15.48     -1.760131           0.0  2025-10-15 14:57:36
# 10     KTB      25.29            500       25.2924         25.00     12646.20       12500.0         -146.20     -1.156079           0.0  2025-10-15 12:06:53
# 11     BTS       2.84            500        2.8488          2.82      1424.40        1410.0          -14.40     -1.010952           0.0  2025-10-15 12:16:47
# 12     VGI       1.33            500        1.3443          1.33       672.15         665.0           -7.15     -1.063751           0.0  2025-10-15 16:26:45
# 13     TLI      10.42            500       10.4175         10.20      5208.75        5100.0         -108.75     -2.087833           0.0  2025-10-15 14:30:29
# 14    COM7      26.79            500       26.7949         26.75     13397.45       13375.0          -22.45     -0.167569           0.0  2025-10-15 15:32:19
# 15     IVL      20.63            100       20.6346         20.40      2063.46        2040.0          -23.46     -1.136925           0.0  2025-10-15 14:24:41
# 16     KTC      31.05            500       31.0521         30.50     15526.05       15250.0         -276.05     -1.777980           0.0  2025-10-15 14:41:52
# 17    MINT      22.54            200       22.5378         22.40      4507.56        4480.0          -27.56     -0.611417           0.0  2025-10-15 14:25:02
# 18      OR      13.82            500       13.8031         13.70      6901.55        6850.0          -51.55     -0.746934           0.0  2025-10-15 16:28:20
# 19    TCAP      50.84            400       50.8353         51.00     20334.12       20400.0           65.88      0.323987           0.0  2025-10-15 14:52:58
# 20   PTTEP     109.18            100      109.1831        108.00     10918.31       10800.0         -118.31     -1.083593           0.0  2025-10-15 14:35:18
# 21    EGCO     137.73            100      137.7310        137.50     13773.10       13750.0          -23.10     -0.167718           0.0  2025-10-15 15:07:18
# 22     BEM       5.11            500        5.1086          5.10      2554.30        2550.0           -4.30     -0.168344           0.0  2025-10-15 15:45:24
# 23     AOT      40.82            500       40.8185         40.75     20409.25       20375.0          -34.25     -0.167816           0.0  2025-10-15 16:24:19
# 24    CCET       5.91            500        5.9099          5.85      2954.95        2925.0          -29.95     -1.013554           0.0  2025-10-15 15:52:39
# 25  TIDLOR      22.04            100       22.0370         22.10      2203.70        2210.0            6.30      0.285883           0.0  2025-10-15 15:47:41
# 26    SCGP      17.53            500       17.5294         17.30      8764.70        8650.0         -114.70     -1.308659           0.0  2025-10-15 15:51:42
# 27     TOP      35.31            500       35.2090         35.00     17604.50       17500.0         -104.50     -0.593598           0.0  2025-10-15 16:25:52
# 28     AWC       2.12            500        2.1316          2.10      1065.80        1050.0          -15.80     -1.482454           0.0  2025-10-15 15:55:40
# 29     BCP      29.30            500       29.2991         28.75     14649.55       14375.0         -274.55     -1.874119           0.0  2025-10-15 16:14:44
# 30    GULF      44.32            100       44.3243         44.25      4432.43        4425.0           -7.43     -0.167628           0.0  2025-10-15 16:21:15
# 31   RATCH      28.30            200       28.2975         29.50      5659.50        5900.0          240.50      4.249492           0.0  2025-10-15 16:29:28
# 32      LH       4.09            100        4.0869          4.06       408.69         406.0           -2.69     -0.658201           0.0  2025-10-15 16:35:20
